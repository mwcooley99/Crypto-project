# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

plt.rcParams["figure.figsize"] = [16,9]

# %%
mydateparser = lambda x: pd.datetime.strptime(x, "%Y %m %d %H:%M:%S")
df = pd.read_json("twitter_data.json", convert_dates=['date'])

# %%
df.head()
# Out:
#                  date                   id  \
# 0 2019-06-17 20:55:26  1140724655080267782
# 1 2019-06-17 20:51:34  1140723684040204288
# 2 2019-06-17 20:49:33  1140723177762500608
# 3 2019-06-17 20:45:51  1140722244798373889
# 4 2019-06-17 20:43:54  1140721755541168129
#
#                                                 text    user_id  \
# 0  @bzogrammer @robinhanson Many algorithms in co...  295218901
# 1  @glibbertarian @robinhanson Not claiming it do...  295218901
# 2  @robinhanson Oh I'm sure there's much better m...  295218901
# 3  @robinhanson I'm not claiming that the effect ...  295218901
# 4  @robinhanson Making it "illegal" from the star...  295218901
#
#         user_name
# 0  VitalikButerin
# 1  VitalikButerin
# 2  VitalikButerin
# 3  VitalikButerin
# 4  VitalikButerin

# %%
day_grouper = df.groupby([pd.Grouper(key="date", freq='D'), "user_name"])
day_count = day_grouper['id'].agg(['count']).reset_index()
day_count.head()
# Out:
#         date  user_name  count
# 0 2011-07-04  rogerkver      1
# 1 2011-07-11  rogerkver      1
# 2 2011-07-23  rogerkver      1
# 3 2011-08-04  rogerkver      1
# 4 2011-08-16  rogerkver      1

# %%
# Look at all users
ax = sns.lineplot(x="date", y="count", hue="user_name", data=day_count)
# Out:
# /Users/TheDoctor/.virtualenvs/Crypto-project/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Filter by date
filter_date = pd.Timestamp(datetime(2018, 1, 1))
date_filtered_count = day_count.loc[day_count['date'] > filter_date]
ax = sns.lineplot(x="date", y="count", hue="user_name", data=date_filtered_count)
fig = ax.get_figure()

# %%
fig, axes = plt.subplots(nrows=10, ncols=1, figsize=(16, 80), sharex=True)
# fig.subplots_adjust(hspace=0.5)
count = 0
for user, ax in zip(day_count['user_name'].unique(), axes.flatten()):
    print(user)
    ax = sns.lineplot(
        x="date", y="count", hue="user_name", ax=ax,
        data=date_filtered_count.loc[date_filtered_count['user_name'] == user])
# Out:
# rogerkver
# ErikVoorhees
# aantonop
# SatoshiLite
# naval
# justinsuntron
# VitalikButerin
# NickSzabo4
# brian_armstrong
# officialmcafee
